# %% [markdown]
# <a href="https://colab.research.google.com/github/lintangiqhtiar/sales-data-performance/blob/main/Sales_Data_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#

# %% [markdown]
# #import google spereadsheet

# %%
# !pip install --upgrade gspread
# !pip install --upgrade oauth2client
# !pip install pandas

import gspread
from google.auth.transport.requests import Request
from google.colab import auth
from google.auth import default
import pandas as pd

# Otorisasi
auth.authenticate_user()
creds, _ = default()
creds.refresh(Request())
gc = gspread.authorize(creds)

# URL dari Google Spreadsheet Anda
sheet_url = 'https://docs.google.com/spreadsheets/d/1YjaalV1FmbjbCQGGtlFizW_M7Qi5ugKbISOF--so93A/edit?gid=1666191194' #kasih akses public dan editor (harus dicoba untuk diprivate)
sheet_url_trf = sheet_url.replace('/edit?gid=', '/export?format=csv&gid=')
print(sheet_url_trf)

# Membaca data dari URL CSV
df = pd.read_csv(sheet_url_trf)
df.head()
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Collecting gspread
#   Downloading gspread-6.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 703.6 kB/s eta 0:00:00
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.7.4)
# Installing collected packages: gspread
#   Attempting uninstall: gspread
#     Found existing installation: gspread 6.0.2
#     Uninstalling gspread-6.0.2:
#       Successfully uninstalled gspread-6.0.2
# Successfully installed gspread-6.1.2
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# https://docs.google.com/spreadsheets/d/1YjaalV1FmbjbCQGGtlFizW_M7Qi5ugKbISOF--so93A/export?format=csv&gid=1666191194
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH      ORDERDATE   STATUS  \
# 0        10100               30     100.00  1/6/2003 0:00  Shipped
# 1        10100               50      67.80  1/6/2003 0:00  Shipped
# 2        10100               22      86.51  1/6/2003 0:00  Shipped
# 3        10100               49      34.47  1/6/2003 0:00  Shipped
# 4        10101               25     100.00  1/9/2003 0:00  Shipped
#
#     PRODUCTLINE PRODUCTCODE                  CUSTOMERNAME       CITY DEALSIZE
# 0  Vintage Cars    S18_1749  Online Diecast Creations Co.     Nashua   Medium
# 1  Vintage Cars    S18_2248  Online Diecast Creations Co.     Nashua   Medium
# 2  Vintage Cars    S18_4409  Online Diecast Creations Co.     Nashua    Small
# 3  Vintage Cars    S24_3969  Online Diecast Creations Co.     Nashua    Small
# 4  Vintage Cars    S18_2325          Blauer See Auto, Co.  Frankfurt   Medium

# %% [markdown]
# #cleaning data

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH      ORDERDATE   STATUS  \
# 0        10100               30     100.00  1/6/2003 0:00  Shipped
# 1        10100               50      67.80  1/6/2003 0:00  Shipped
# 2        10100               22      86.51  1/6/2003 0:00  Shipped
# 3        10100               49      34.47  1/6/2003 0:00  Shipped
# 4        10101               25     100.00  1/9/2003 0:00  Shipped
#
#     PRODUCTLINE PRODUCTCODE                  CUSTOMERNAME       CITY DEALSIZE
# 0  Vintage Cars    S18_1749  Online Diecast Creations Co.     Nashua   Medium
# 1  Vintage Cars    S18_2248  Online Diecast Creations Co.     Nashua   Medium
# 2  Vintage Cars    S18_4409  Online Diecast Creations Co.     Nashua    Small
# 3  Vintage Cars    S24_3969  Online Diecast Creations Co.     Nashua    Small
# 4  Vintage Cars    S18_2325          Blauer See Auto, Co.  Frankfurt   Medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2824 entries, 0 to 2823
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ORDERNUMBER      2824 non-null   int64
#  1   QUANTITYORDERED  2824 non-null   int64
#  2   PRICEEACH        2824 non-null   float64
#  3   ORDERDATE        2824 non-null   object
#  4   STATUS           2824 non-null   object
#  5   PRODUCTLINE      2824 non-null   object
#  6   PRODUCTCODE      2824 non-null   object
#  7   CUSTOMERNAME     2824 non-null   object
#  8   CITY             2824 non-null   object
#  9   DEALSIZE         2824 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 220.8+ KB

# %%
#membuat data frame baru untuk dibersihkan
df_cleaned = df.copy()

#merubah tipe date time nya
df_cleaned['ORDERDATE'] = pd.to_datetime(df_cleaned['ORDERDATE'])
df_cleaned.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERDATE   STATUS   PRODUCTLINE  \
# 0        10100               30     100.00 2003-01-06  Shipped  Vintage Cars
# 1        10100               50      67.80 2003-01-06  Shipped  Vintage Cars
# 2        10100               22      86.51 2003-01-06  Shipped  Vintage Cars
# 3        10100               49      34.47 2003-01-06  Shipped  Vintage Cars
# 4        10101               25     100.00 2003-01-09  Shipped  Vintage Cars
#
#   PRODUCTCODE                  CUSTOMERNAME       CITY DEALSIZE
# 0    S18_1749  Online Diecast Creations Co.     Nashua   Medium
# 1    S18_2248  Online Diecast Creations Co.     Nashua   Medium
# 2    S18_4409  Online Diecast Creations Co.     Nashua    Small
# 3    S24_3969  Online Diecast Creations Co.     Nashua    Small
# 4    S18_2325          Blauer See Auto, Co.  Frankfurt   Medium

# %%
df_cleaned['DEALSIZE'].value_counts()

for col_name in ['STATUS', 'PRODUCTLINE', 'DEALSIZE', 'CITY']:
  print(df_cleaned[col_name].value_counts(), '\n')
# Out:
# STATUS
# Shipped       2618
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: count, dtype: int64
#
# PRODUCTLINE
# Classic Cars        967
# Vintage Cars        608
# Motorcycles         331
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
# Name: count, dtype: int64
#
# DEALSIZE
# Medium    1384
# Small     1283
# Large      157
# Name: count, dtype: int64
#
# CITY
# Madrid            304
# San Rafael        180
# NYC               152
# Singapore          79
# Paris              70
#                  ...
# South Brisbane     15
# Los Angeles        14
# Munich             14
# Burbank            13
# Charleroi           8
# Name: count, Length: 73, dtype: int64

# %%
duplicates = df_cleaned.duplicated()
print("Apakah ada duplikat dalam data?:")
print(duplicates)

# Menampilkan baris yang merupakan duplikat
duplicate_rows = df_cleaned[df_cleaned.duplicated()]
print("\nBaris yang duplikat:")
print(duplicate_rows)
# Out:
# Apakah ada duplikat dalam data?:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# 2823    False
# Length: 2824, dtype: bool
#
# Baris yang duplikat:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERDATE   STATUS  \
# 121        10111               28      64.33 2003-03-25  Shipped
#
#       PRODUCTLINE PRODUCTCODE     CUSTOMERNAME           CITY DEALSIZE
# 121  Vintage Cars    S18_2957  Mini Wheels Co.  San Francisco    Small

# %%
# Menghapus data duplikat dan menyimpan ke dalam DataFrame baru
data_cleaned = df_cleaned.drop_duplicates()

# Menampilkan data setelah penghapusan duplikat
print("\nData setelah menghapus duplikat:")
print(data_cleaned)
# Out:
# Data setelah menghapus duplikat:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERDATE      STATUS  \
# 0           10100               30     100.00 2003-01-06     Shipped
# 1           10100               50      67.80 2003-01-06     Shipped
# 2           10100               22      86.51 2003-01-06     Shipped
# 3           10100               49      34.47 2003-01-06     Shipped
# 4           10101               25     100.00 2003-01-09     Shipped
# ...           ...              ...        ...        ...         ...
# 2819        10425               49     100.00 2005-05-31  In Process
# 2820        10425               31      33.24 2005-05-31  In Process
# 2821        10425               41      86.68 2005-05-31  In Process
# 2822        10425               11      43.83 2005-05-31  In Process
# 2823        10425               18     100.00 2005-05-31  In Process
#
#            PRODUCTLINE PRODUCTCODE                  CUSTOMERNAME       CITY  \
# 0         Vintage Cars    S18_1749  Online Diecast Creations Co.     Nashua
# 1         Vintage Cars    S18_2248  Online Diecast Creations Co.     Nashua
# 2         Vintage Cars    S18_4409  Online Diecast Creations Co.     Nashua
# 3         Vintage Cars    S24_3969  Online Diecast Creations Co.     Nashua
# 4         Vintage Cars    S18_2325          Blauer See Auto, Co.  Frankfurt
# ...                ...         ...                           ...        ...
# 2819  Trucks and Buses    S24_2300             La Rochelle Gifts     Nantes
# 2820      Classic Cars    S24_2840             La Rochelle Gifts     Nantes
# 2821  Trucks and Buses    S32_1268             La Rochelle Gifts     Nantes
# 2822  Trucks and Buses    S32_2509             La Rochelle Gifts     Nantes
# 2823  Trucks and Buses    S50_1392             La Rochelle Gifts     Nantes
#
#      DEALSIZE
# 0      Medium
# 1      Medium
# 2       Small
# 3       Small
# 4      Medium
# ...       ...
# 2819   Medium
# 2820    Small
# 2821   Medium
# 2822    Small
# 2823    Small
#
# [2823 rows x 10 columns]

# %%
df_cleaned['REVENUE'] = df_cleaned['QUANTITYORDERED'] * df_cleaned['PRICEEACH']
df_cleaned.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERDATE   STATUS   PRODUCTLINE  \
# 0        10100               30     100.00 2003-01-06  Shipped  Vintage Cars
# 1        10100               50      67.80 2003-01-06  Shipped  Vintage Cars
# 2        10100               22      86.51 2003-01-06  Shipped  Vintage Cars
# 3        10100               49      34.47 2003-01-06  Shipped  Vintage Cars
# 4        10101               25     100.00 2003-01-09  Shipped  Vintage Cars
#
#   PRODUCTCODE                  CUSTOMERNAME       CITY DEALSIZE  REVENUE
# 0    S18_1749  Online Diecast Creations Co.     Nashua   Medium  3000.00
# 1    S18_2248  Online Diecast Creations Co.     Nashua   Medium  3390.00
# 2    S18_4409  Online Diecast Creations Co.     Nashua    Small  1903.22
# 3    S24_3969  Online Diecast Creations Co.     Nashua    Small  1689.03
# 4    S18_2325          Blauer See Auto, Co.  Frankfurt   Medium  2500.00

# %% [markdown]
# #EDA

# %% [markdown]
# highest and lowest of Product Line

# %%
y=df_cleaned.groupby(['PRODUCTLINE']).size().reset_index(name='counts') #menghitung jumlah rating yang tersedia
print(y)
# Out:
#         PRODUCTLINE  counts
# 0      Classic Cars     967
# 1       Motorcycles     331
# 2            Planes     306
# 3             Ships     234
# 4            Trains      77
# 5  Trucks and Buses     301
# 6      Vintage Cars     608

# %%
plt.rcParams["figure.figsize"] = (10,5)
sns.barplot( x='PRODUCTLINE', y='counts', data = y.sort_values('counts', ascending=False))

#labeling
plt.xlabel('Product Line')
plt.ylabel('Total Count')
plt.title('Bar Chart of Product Line Sales')
plt.show()

# %%
# Identify the highest and lowest values
highest = y.loc[y['counts'].idxmax()]
lowest = y.loc[y['counts'].idxmin()]

# Plot the bar chart
plt.figure(figsize=(10, 6))

# Plot all bars
bars = plt.bar(y['PRODUCTLINE'], y['counts'], color='gray')

# Highlight the highest and lowest bars
bars[y['counts'].idxmax()].set_color('green')
bars[y['counts'].idxmin()].set_color('red')

# Add labels and title
plt.xlabel('Product Line')
plt.ylabel('Total Count')
plt.title('Bar Chart with Highest (Green) and Lowest (Red) Values')
plt.show()

# %% [markdown]
# **Insight**: The product line with the highest sales is Classic Cars, while the product line with the lowest sales is Trains.

# %% [markdown]
# ##Sales Performance Over Time

# %%
data_sales=df_cleaned.groupby(['ORDERDATE','REVENUE']).size().reset_index(name='counts')
data_sales.head()
# Out:
#    ORDERDATE  REVENUE  counts
# 0 2003-01-06  1689.03       1
# 1 2003-01-06  1903.22       1
# 2 2003-01-06  3000.00       1
# 3 2003-01-06  3390.00       1
# 4 2003-01-09  1404.00       1

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='ORDERDATE', y='REVENUE', data=data_sales)

#add label and title
plt.xlabel('Order Date')
plt.ylabel('Revenue')
plt.title('Sales Performance Over Time')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot('ORDERDATE','REVENUE', data=data_sales)

#add label and title
plt.xlabel('Order Date')
plt.ylabel('Revenue')
plt.title('Sales Performance Over Time')
plt.show()

# %%
# Set kolom 'date' sebagai index
data_sales.set_index('ORDERDATE', inplace=True)

# Menghitung total revenue per bulan
monthly_revenue = data_sales['REVENUE'].resample('M').sum().reset_index(name='TotalRevenue')

# Menampilkan total revenue per bulan
print(monthly_revenue)

monthly_revenue.info()
# Out:
#     ORDERDATE  TotalRevenue
# 0  2003-01-31      97585.96
# 1  2003-02-28     117836.80
# 2  2003-03-31     137796.23
# 3  2003-04-30     162421.03
# 4  2003-05-31     159854.12
# 5  2003-06-30     121752.84
# 6  2003-07-31     143069.73
# 7  2003-08-31     159426.32
# 8  2003-09-30     200945.86
# 9  2003-10-31     463940.57
# 10 2003-11-30     770403.27
# 11 2003-12-31     199217.21
# 12 2004-01-31     250915.87
# 13 2004-02-29     239989.05
# 14 2004-03-31     156158.56
# 15 2004-04-30     165135.80
# 16 2004-05-31     213215.14
# 17 2004-06-30     234590.75
# 18 2004-07-31     258003.61
# 19 2004-08-31     364806.59
# 20 2004-09-30     242254.26
# 21 2004-10-31     414996.13
# 22 2004-11-30     838979.18
# 23 2004-12-31     281555.93
# 24 2005-01-31     275980.46
# 25 2005-02-28     272802.30
# 26 2005-03-31     305731.94
# 27 2005-04-30     211377.63
# 28 2005-05-31     358143.65
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORDERDATE     29 non-null     datetime64[ns]
#  1   TotalRevenue  29 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 592.0 bytes

# %%
#membuat line chart
plt.figure(figsize=(10,6))
plt.plot('ORDERDATE','TotalRevenue',data=monthly_revenue)

#add title and label
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.title('Sales Performance Monthly Revenue')
plt.show()

# %% [markdown]
# ##Corelate Deal Size with Total Sales

# %%
data_corelate=df_cleaned.groupby(['DEALSIZE','REVENUE']).size().reset_index(name='counts')
data_corelate.head()
# Out:
#   DEALSIZE  REVENUE  counts
# 0    Large   2900.0       2
# 1    Large   3100.0       1
# 2    Large   3200.0       2
# 3    Large   3300.0       3
# 4    Large   3400.0       2

# %%
# Mengelompokkan data berdasarkan 'DEALSIZE' dan menghitung total pendapatan
total_revenue_per_jenis = data_corelate.groupby('DEALSIZE')['REVENUE'].sum().reset_index(name='TotalRevenue')

# Menghitung jumlah total per 'DEALSIZE'
total_count_per_jenis = data_corelate.groupby('DEALSIZE').size().reset_index(name='TotalCount')

# Menggabungkan kedua DataFrame berdasarkan 'DEALSIZE'
result = total_revenue_per_jenis.merge(total_count_per_jenis, on='DEALSIZE')

# Menampilkan hasil
print(result)
# Out:
#   DEALSIZE  TotalRevenue  TotalCount
# 0    Large     185657.91          36
# 1   Medium    1581241.28         435
# 2    Small    2185711.46        1105

# %%
plt.figure(figsize=(10, 6))

# Menggunakan warna untuk mewakili TotalRevenue
scatter = plt.scatter(result['TotalCount'], result['DEALSIZE'], c=result['TotalRevenue'], cmap='viridis', s=100, alpha=0.7)

# Menambahkan title dan label
plt.xlabel('Total Count')
plt.ylabel('Deal Size')
plt.title('Correlation between Deal Size and Total Sales')

# Menambahkan color bar untuk menunjukkan TotalRevenue
colorbar = plt.colorbar(scatter)
colorbar.set_label('Total Revenue')

# Menampilkan plot
plt.show()

# %% [markdown]
# **Insight**: The correlation between deal size and total sales is positive.

# %% [markdown]
# ##Persentage of contribution for each type deal

# %%
result.head()
# Out:
#   DEALSIZE  TotalRevenue  TotalCount
# 0    Large     185657.91          36
# 1   Medium    1581241.28         435
# 2    Small    2185711.46        1105

# %%
plt.pie(result['TotalRevenue'], labels=result['DEALSIZE'], autopct='%1.1f%%')
plt.title('Persentage of contribution for each type deal')
plt.show()

# %% [markdown]
# #Saving Cleaned Data to CSV

# %%
from google.colab import files

# Saving the cleaned DataFrame to a CSV file
df_cleaned.to_csv('cleaned_sales_data.csv', index=False)

# Download the file
files.download('cleaned_sales_data.csv')
